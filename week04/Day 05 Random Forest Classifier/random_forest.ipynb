# %% [markdown]
# # Random Forest Classifier & its Comparison of Hotel Booking Pridictions

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from folium.plugins import HeatMap
import plotly.express as px

# %%
# reading data
df = pd.read_csv('hotel_bookings.csv')
df.head(20)
# Out:
#            hotel  is_canceled  ...  reservation_status  reservation_status_date
# 0   Resort Hotel            0  ...           Check-Out               2015-07-01
# 1   Resort Hotel            0  ...           Check-Out               2015-07-01
# 2   Resort Hotel            0  ...           Check-Out               2015-07-02
# 3   Resort Hotel            0  ...           Check-Out               2015-07-02
# 4   Resort Hotel            0  ...           Check-Out               2015-07-03
# 5   Resort Hotel            0  ...           Check-Out               2015-07-03
# 6   Resort Hotel            0  ...           Check-Out               2015-07-03
# 7   Resort Hotel            0  ...           Check-Out               2015-07-03
# 8   Resort Hotel            1  ...            Canceled               2015-05-06
# 9   Resort Hotel            1  ...            Canceled               2015-04-22
# 10  Resort Hotel            1  ...            Canceled               2015-06-23
# ...

# %%
df.describe()
# Out:
#          is_canceled  ...  total_of_special_requests
# count  119390.000000  ...              119390.000000
# mean        0.370416  ...                   0.571363
# std         0.482918  ...                   0.792798
# min         0.000000  ...                   0.000000
# 25%         0.000000  ...                   0.000000
# 50%         0.000000  ...                   0.000000
# 75%         1.000000  ...                   1.000000
# max         1.000000  ...                   5.000000
#
# [8 rows x 20 columns]

# %%
# chek info about data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
# checking for null values
null = pd.DataFrame({'Null Values: ':df.isnull().sum(), 'Null Percentage: ': (df.isnull().sum()/df.shape[0]) * 100})
print(null)
# checking percentage of null values
# Out:
#                                 Null Values:   Null Percentage:
# hotel                                       0           0.000000
# is_canceled                                 0           0.000000
# lead_time                                   0           0.000000
# arrival_date_year                           0           0.000000
# arrival_date_month                          0           0.000000
# arrival_date_week_number                    0           0.000000
# arrival_date_day_of_month                   0           0.000000
# stays_in_weekend_nights                     0           0.000000
# stays_in_week_nights                        0           0.000000
# adults                                      0           0.000000
# children                                    4           0.003350
# babies                                      0           0.000000
# meal                                        0           0.000000
# ...

# %%
# filling null values with zero
df.fillna(0, inplace=True)

# %%
df.shape
# Out:
# (119390, 32)

# %%
# adults, babies and children can't be zero at same time, so drop
filter = (df.children == 0) & (df.adults == 0) & (df.babies == 0)
df[filter]
# Out:
#                hotel  is_canceled  ...  reservation_status  reservation_status_date
# 2224    Resort Hotel            0  ...           Check-Out               2015-10-06
# 2409    Resort Hotel            0  ...           Check-Out               2015-10-12
# 3181    Resort Hotel            0  ...           Check-Out               2015-11-23
# 3684    Resort Hotel            0  ...           Check-Out               2016-01-04
# 3708    Resort Hotel            0  ...           Check-Out               2016-01-05
# ...              ...          ...  ...                 ...                      ...
# 115029    City Hotel            0  ...           Check-Out               2017-06-30
# 115091    City Hotel            0  ...           Check-Out               2017-07-01
# 116251    City Hotel            0  ...           Check-Out               2017-07-17
# 116534    City Hotel            0  ...           Check-Out               2017-07-22
# ...

# %%
df = df[~filter]
df
# Out:
#                hotel  is_canceled  ...  reservation_status  reservation_status_date
# 0       Resort Hotel            0  ...           Check-Out               2015-07-01
# 1       Resort Hotel            0  ...           Check-Out               2015-07-01
# 2       Resort Hotel            0  ...           Check-Out               2015-07-02
# 3       Resort Hotel            0  ...           Check-Out               2015-07-02
# 4       Resort Hotel            0  ...           Check-Out               2015-07-03
# ...              ...          ...  ...                 ...                      ...
# 119385    City Hotel            0  ...           Check-Out               2017-09-06
# 119386    City Hotel            0  ...           Check-Out               2017-09-07
# 119387    City Hotel            0  ...           Check-Out               2017-09-07
# 119388    City Hotel            0  ...           Check-Out               2017-09-07
# ...

# %%
df[filter]
# Out:
# C:\Users\asad\AppData\Local\Temp\ipykernel_1536\1940024178.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[filter]
# Empty DataFrame
# Columns: [hotel, is_canceled, lead_time, arrival_date_year, arrival_date_month, arrival_date_week_number, arrival_date_day_of_month, stays_in_weekend_nights, stays_in_week_nights, adults, children, babies, meal, country, market_segment, distribution_channel, is_repeated_guest, previous_cancellations, previous_bookings_not_canceled, reserved_room_type, assigned_room_type, booking_changes, deposit_type, agent, company, days_in_waiting_list, customer_type, adr, required_car_parking_spaces, total_of_special_requests, reservation_status, reservation_status_date]
# Index: []

# %%
df.shape
# Out:
# (119210, 32)

# %% [markdown]
# # Explotary Data Analysis
#
# from where the most guests are coming?

# %%
# selecting country wise guests is_canceled == 0
country_wise_guests = df[df['is_canceled'] == 0] ['country'].value_counts
country_wise_guests.
