# %% [markdown]
# # Overfitting (High Variance) Example for Decision Tree Classifier

# %%
# synthetic classification dataset
from sklearn.datasets import make_classification
# define dataset
X, y = make_classification(n_samples=10000, n_features=20, n_informative=15, n_redundant=5, random_state=13)
# summarize the dataset
print(X.shape, y.shape)
# Out:
# (10000, 20) (10000,)

# %%
from sklearn.model_selection import train_test_split
# split into train test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
# summarize the shape of the train and test sets
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (7000, 20) (3000, 20) (7000,) (3000,)

# %%
# define the tree depths to evaluate
depth_values = [i for i in range(1, 41)]

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
# evaluate a decision tree for each depth
test_scores= []
train_scores=[]
for i in depth_values:
	# configure the model
	model = DecisionTreeClassifier(max_depth=i)
	# fit model on the training dataset
	model.fit(X_train, y_train)
	# evaluate on the train dataset
	train_yhat = model.predict(X_train)
	train_acc = metrics.accuracy_score(y_train, train_yhat)
	train_scores.append(train_acc)
	# evaluate on the test dataset
	test_yhat = model.predict(X_test)
	test_acc = metrics.accuracy_score(y_test, test_yhat)
	test_scores.append(test_acc)
	# summarize progress
	print('>%d, train: %.3f, test: %.3f' % (i, train_acc, test_acc))
# Out:
# >1, train: 0.692, test: 0.658
# >2, train: 0.741, test: 0.713
# >3, train: 0.788, test: 0.763
# >4, train: 0.827, test: 0.798
# >5, train: 0.866, test: 0.835
# >6, train: 0.901, test: 0.860
# >7, train: 0.932, test: 0.872
# >8, train: 0.948, test: 0.877
# >9, train: 0.965, test: 0.882
# >10, train: 0.976, test: 0.880
# >11, train: 0.983, test: 0.889
# >12, train: 0.990, test: 0.886
# >13, train: 0.994, test: 0.883
# >14, train: 0.996, test: 0.878
# >15, train: 0.998, test: 0.880
# >16, train: 0.998, test: 0.878
# >17, train: 0.999, test: 0.882
# >18, train: 1.000, test: 0.883
# >19, train: 1.000, test: 0.880
# >20, train: 1.000, test: 0.884
# >21, train: 1.000, test: 0.884
# >22, train: 1.000, test: 0.883
# >23, train: 1.000, test: 0.880
# >24, train: 1.000, test: 0.880
# >25, train: 1.000, test: 0.881
# >26, train: 1.000, test: 0.883
# >27, train: 1.000, test: 0.881
# >28, train: 1.000, test: 0.881
# >29, train: 1.000, test: 0.883
# >30, train: 1.000, test: 0.883
# >31, train: 1.000, test: 0.882
# >32, train: 1.000, test: 0.879
# >33, train: 1.000, test: 0.880
# >34, train: 1.000, test: 0.880
# >35, train: 1.000, test: 0.884
# >36, train: 1.000, test: 0.879
# >37, train: 1.000, test: 0.885
# >38, train: 1.000, test: 0.880
# >39, train: 1.000, test: 0.885
# >40, train: 1.000, test: 0.883

# %%
from matplotlib import pyplot
pyplot.plot(depth_values, train_scores, '-o', label='Train')
pyplot.plot(depth_values, test_scores, '-o', label='Test')
pyplot.legend()
pyplot.show()

# %%
from sklearn.tree import export_graphviz,plot_tree
plot_tree(model)
# Out:
# [Text(0.5909415399588659, 0.975, 'x[3] <= 0.446\ngini = 0.5\nsamples = 7000\nvalue = [3471, 3529]'),
#  Text(0.3086000624357279, 0.925, 'x[9] <= -0.63\ngini = 0.452\nsamples = 4077\nvalue = [2671, 1406]'),
#  Text(0.1434185397385045, 0.875, 'x[17] <= 0.154\ngini = 0.485\nsamples = 1310\nvalue = [541, 769]'),
#  Text(0.09042162479800206, 0.825, 'x[7] <= 0.348\ngini = 0.479\nsamples = 733\nvalue = [442, 291]'),
#  Text(0.0452475392977817, 0.775, 'x[14] <= 1.098\ngini = 0.401\nsamples = 497\nvalue = [359, 138]'),
#  Text(0.024092845600117527, 0.725, 'x[11] <= 0.29\ngini = 0.262\nsamples = 342\nvalue = [289, 53]'),
#  Text(0.010577346848832084, 0.675, 'x[5] <= -2.72\ngini = 0.486\nsamples = 60\nvalue = [25, 35]'),
#  Text(0.0047010430439253705, 0.625, 'x[7] <= -5.201\ngini = 0.095\nsamples = 20\nvalue = [1, 19]'),
#  Text(0.0023505215219626853, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.007051564565888057, 0.575, 'gini = 0.0\nsamples = 19\nvalue = [0, 19]'),
#  Text(0.0164536506537388, 0.625, 'x[14] <= -0.427\ngini = 0.48\nsamples = 40\nvalue = [24, 16]'),
#  Text(0.011752607609813427, 0.575, 'x[19] <= 1.703\ngini = 0.32\nsamples = 25\nvalue = [20, 5]'),
#  Text(0.009402086087850741, 0.525, 'x[6] <= -11.793\ngini = 0.227\nsamples = 23\nvalue = [20, 3]'),
#  Text(0.007051564565888057, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.011752607609813427, 0.475, 'x[3] <= -0.225\ngini = 0.165\nsamples = 22\nvalue = [20, 2]'),
#  Text(0.009402086087850741, 0.425, 'x[13] <= 3.909\ngini = 0.091\nsamples = 21\nvalue = [20, 1]'),
#  Text(0.007051564565888057, 0.375, 'x[8] <= -0.592\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.0047010430439253705, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.009402086087850741, 0.325, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.011752607609813427, 0.375, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(0.014103129131776113, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.014103129131776113, 0.525, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.021154693697664168, 0.575, 'x[7] <= -1.447\ngini = 0.391\nsamples = 15\nvalue = [4, 11]'),
#  Text(0.018804172175701482, 0.525, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.023505215219626854, 0.525, 'x[10] <= -3.361\ngini = 0.153\nsamples = 12\nvalue = [1, 11]'),
#  Text(0.021154693697664168, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.02585573674158954, 0.475, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.037608344351402964, 0.675, 'x[2] <= -1.818\ngini = 0.12\nsamples = 282\nvalue = [264, 18]'),
#  Text(0.0329073013074776, 0.625, 'x[12] <= -0.93\ngini = 0.499\nsamples = 21\nvalue = [11, 10]'),
#  Text(0.030556779785514913, 0.575, 'x[2] <= -13.046\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.028206258263552227, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0329073013074776, 0.525, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.03525782282944028, 0.575, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.042309387395328336, 0.625, 'x[5] <= -4.411\ngini = 0.059\nsamples = 261\nvalue = [253, 8]'),
#  Text(0.039958865873365654, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.044659908917291026, 0.575, 'x[9] <= -7.101\ngini = 0.052\nsamples = 260\nvalue = [253, 7]'),
#  Text(0.042309387395328336, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.04701043043925371, 0.525, 'x[15] <= 4.111\ngini = 0.045\nsamples = 259\nvalue = [253, 6]'),
#  Text(0.040546496253856326, 0.475, 'x[0] <= -5.216\ngini = 0.038\nsamples = 256\nvalue = [251, 5]'),
#  Text(0.03467019244894961, 0.425, 'x[12] <= 1.541\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.032319670926986926, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.0370207139709123, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.046422800058763036, 0.425, 'x[6] <= -7.459\ngini = 0.031\nsamples = 253\nvalue = [249, 4]'),
#  Text(0.041721757014837664, 0.375, 'x[16] <= -1.49\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.03937123549287498, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.044072278536800354, 0.325, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.05112384310268841, 0.375, 'x[14] <= 0.204\ngini = 0.024\nsamples = 248\nvalue = [245, 3]'),
#  Text(0.048773321580725726, 0.325, 'gini = 0.0\nsamples = 205\nvalue = [205, 0]'),
#  Text(0.05347436462465109, 0.325, 'x[3] <= 0.255\ngini = 0.13\nsamples = 43\nvalue = [40, 3]'),
#  Text(0.05112384310268841, 0.275, 'x[14] <= 0.232\ngini = 0.091\nsamples = 42\nvalue = [40, 2]'),
#  Text(0.048773321580725726, 0.225, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.05347436462465109, 0.225, 'x[17] <= -0.055\ngini = 0.048\nsamples = 41\nvalue = [40, 1]'),
#  Text(0.05112384310268841, 0.175, 'gini = 0.0\nsamples = 40\nvalue = [40, 0]'),
#  Text(0.05582488614661378, 0.175, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.05582488614661378, 0.275, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.05347436462465109, 0.475, 'x[19] <= -3.293\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.05112384310268841, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.05582488614661378, 0.425, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.06640223299544587, 0.725, 'x[16] <= 2.406\ngini = 0.495\nsamples = 155\nvalue = [70, 85]'),
#  Text(0.05817540766857646, 0.675, 'x[12] <= 0.19\ngini = 0.178\nsamples = 81\nvalue = [8, 73]'),
#  Text(0.05582488614661378, 0.625, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.06052592919053915, 0.625, 'x[16] <= 0.36\ngini = 0.12\nsamples = 78\nvalue = [5, 73]'),
#  Text(0.05817540766857646, 0.575, 'gini = 0.0\nsamples = 59\nvalue = [0, 59]'),
#  Text(0.06287645071250184, 0.575, 'x[1] <= -0.797\ngini = 0.388\nsamples = 19\nvalue = [5, 14]'),
#  Text(0.06052592919053915, 0.525, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.06522697223446453, 0.525, 'x[3] <= -2.648\ngini = 0.219\nsamples = 16\nvalue = [2, 14]'),
#  Text(0.06287645071250184, 0.475, 'x[14] <= 4.358\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.06052592919053915, 0.425, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.06522697223446453, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0675774937564272, 0.475, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(0.07462905832231527, 0.675, 'x[9] <= -3.677\ngini = 0.272\nsamples = 74\nvalue = [62, 12]'),
#  Text(0.06992801527838989, 0.625, 'x[5] <= 1.656\ngini = 0.42\nsamples = 10\nvalue = [3, 7]'),
#  Text(0.0675774937564272, 0.575, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.07227853680035258, 0.575, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.07933010136624064, 0.625, 'x[5] <= -2.79\ngini = 0.144\nsamples = 64\nvalue = [59, 5]'),
#  Text(0.07697957984427795, 0.575, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.08168062288820332, 0.575, 'x[17] <= -0.078\ngini = 0.092\nsamples = 62\nvalue = [59, 3]'),
#  Text(0.07933010136624064, 0.525, 'x[11] <= -2.772\ngini = 0.063\nsamples = 61\nvalue = [59, 2]'),
#  Text(0.07697957984427795, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08168062288820332, 0.475, 'x[10] <= 4.487\ngini = 0.033\nsamples = 60\nvalue = [59, 1]'),
#  Text(0.07933010136624064, 0.425, 'gini = 0.0\nsamples = 58\nvalue = [58, 0]'),
#  Text(0.084031144410166, 0.425, 'x[0] <= 1.983\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.08168062288820332, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08638166593212869, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.084031144410166, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.13559571029822243, 0.775, 'x[5] <= 1.377\ngini = 0.456\nsamples = 236\nvalue = [83, 153]'),
#  Text(0.10665491405905686, 0.725, 'x[19] <= -3.354\ngini = 0.324\nsamples = 162\nvalue = [33, 129]'),
#  Text(0.09343323049801674, 0.675, 'x[10] <= -0.123\ngini = 0.469\nsamples = 32\nvalue = [20, 12]'),
#  Text(0.08873218745409138, 0.625, 'x[3] <= -4.983\ngini = 0.391\nsamples = 15\nvalue = [4, 11]'),
#  Text(0.08638166593212869, 0.575, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.09108270897605406, 0.575, 'x[12] <= -0.039\ngini = 0.26\nsamples = 13\nvalue = [2, 11]'),
#  Text(0.08873218745409138, 0.525, 'x[5] <= -1.823\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.08638166593212869, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.09108270897605406, 0.475, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.09343323049801674, 0.525, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.09813427354194212, 0.625, 'x[14] <= 1.979\ngini = 0.111\nsamples = 17\nvalue = [16, 1]'),
#  Text(0.09578375201997943, 0.575, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(0.1004847950639048, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.11987659762009696, 0.675, 'x[16] <= -4.325\ngini = 0.18\nsamples = 130\nvalue = [13, 117]'),
#  Text(0.10753635962979285, 0.625, 'x[14] <= -2.225\ngini = 0.484\nsamples = 17\nvalue = [7, 10]'),
#  Text(0.10518583810783018, 0.575, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.10988688115175554, 0.575, 'x[8] <= -3.092\ngini = 0.355\nsamples = 13\nvalue = [3, 10]'),
#  Text(0.10753635962979285, 0.525, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.11223740267371823, 0.525, 'x[16] <= -4.731\ngini = 0.165\nsamples = 11\nvalue = [1, 10]'),
#  Text(0.10988688115175554, 0.475, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.11458792419568092, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.13221683561040107, 0.625, 'x[10] <= 3.107\ngini = 0.101\nsamples = 113\nvalue = [6, 107]'),
#  Text(0.12634053180549434, 0.575, 'x[18] <= 2.29\ngini = 0.07\nsamples = 110\nvalue = [4, 106]'),
#  Text(0.12163948876156898, 0.525, 'x[19] <= -3.223\ngini = 0.02\nsamples = 98\nvalue = [1, 97]'),
#  Text(0.11928896723960629, 0.475, 'x[19] <= -3.3\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.1169384457176436, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12163948876156898, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.12399001028353165, 0.475, 'gini = 0.0\nsamples = 96\nvalue = [0, 96]'),
#  Text(0.13104157484941972, 0.525, 'x[10] <= -0.926\ngini = 0.375\nsamples = 12\nvalue = [3, 9]'),
#  Text(0.12869105332745703, 0.475, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.1333920963713824, 0.475, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.13809313941530776, 0.575, 'x[15] <= -2.304\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.13574261789334507, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.14044366093727045, 0.525, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.164536506537388, 0.725, 'x[14] <= 3.106\ngini = 0.438\nsamples = 74\nvalue = [50, 24]'),
#  Text(0.1580725723519906, 0.675, 'x[2] <= 13.936\ngini = 0.316\nsamples = 61\nvalue = [49, 12]'),
#  Text(0.15219626854708387, 0.625, 'x[9] <= -3.767\ngini = 0.171\nsamples = 53\nvalue = [48, 5]'),
#  Text(0.14749522550315852, 0.575, 'x[11] <= 9.179\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.14514470398119583, 0.525, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.1498457470251212, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.15689731159100925, 0.575, 'x[19] <= 3.539\ngini = 0.078\nsamples = 49\nvalue = [47, 2]'),
#  Text(0.15454679006904656, 0.525, 'x[1] <= -2.384\ngini = 0.041\nsamples = 48\nvalue = [47, 1]'),
#  Text(0.15219626854708387, 0.475, 'x[12] <= 1.851\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.1498457470251212, 0.425, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.15454679006904656, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.15689731159100925, 0.475, 'gini = 0.0\nsamples = 45\nvalue = [45, 0]'),
#  Text(0.15924783311297194, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.16394887615689732, 0.625, 'x[13] <= 4.584\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.16159835463493463, 0.575, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.16629939767885998, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.17100044072278536, 0.675, 'x[2] <= 12.282\ngini = 0.142\nsamples = 13\nvalue = [1, 12]'),
#  Text(0.16864991920082267, 0.625, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.17335096224474805, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1964154546790069, 0.825, 'x[18] <= -3.614\ngini = 0.284\nsamples = 577\nvalue = [99, 478]'),
#  Text(0.17922726604965478, 0.775, 'x[7] <= 0.665\ngini = 0.287\nsamples = 23\nvalue = [19, 4]'),
#  Text(0.1768767445276921, 0.725, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]'),
#  Text(0.18157778757161747, 0.725, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.21360364330835904, 0.775, 'x[2] <= 5.751\ngini = 0.247\nsamples = 554\nvalue = [80, 474]'),
#  Text(0.18627883061554282, 0.725, 'x[16] <= 10.055\ngini = 0.123\nsamples = 366\nvalue = [24, 342]'),
#  Text(0.18392830909358013, 0.675, 'x[12] <= -1.407\ngini = 0.1\nsamples = 361\nvalue = [19, 342]'),
#  Text(0.17805200528867343, 0.625, 'x[3] <= -0.775\ngini = 0.405\nsamples = 46\nvalue = [13, 33]'),
#  Text(0.17335096224474805, 0.575, 'x[7] <= 1.639\ngini = 0.465\nsamples = 19\nvalue = [12, 7]'),
#  Text(0.17100044072278536, 0.525, 'x[4] <= 2.581\ngini = 0.245\nsamples = 14\nvalue = [12, 2]'),
#  Text(0.16864991920082267, 0.475, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.17335096224474805, 0.475, 'x[0] <= 0.522\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.17100044072278536, 0.425, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.17570148376671074, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.17570148376671074, 0.525, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.18275304833259878, 0.575, 'x[1] <= -2.805\ngini = 0.071\nsamples = 27\nvalue = [1, 26]'),
#  Text(0.18040252681063612, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.18510356985456147, 0.525, 'gini = 0.0\nsamples = 26\nvalue = [0, 26]'),
#  Text(0.18980461289848685, 0.625, 'x[4] <= -6.065\ngini = 0.037\nsamples = 315\nvalue = [6, 309]'),
#  Text(0.18745409137652416, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.19215513442044954, 0.575, 'x[11] <= 8.483\ngini = 0.031\nsamples = 314\nvalue = [5, 309]'),
#  Text(0.18980461289848685, 0.525, 'x[14] <= -4.119\ngini = 0.025\nsamples = 313\nvalue = [4, 309]'),
#  Text(0.18510356985456147, 0.475, 'x[11] <= -2.844\ngini = 0.278\nsamples = 12\nvalue = [2, 10]'),
#  Text(0.18275304833259878, 0.425, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.18745409137652416, 0.425, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.19450565594241223, 0.475, 'x[17] <= 0.357\ngini = 0.013\nsamples = 301\nvalue = [2, 299]'),
#  Text(0.19215513442044954, 0.425, 'x[4] <= -2.391\ngini = 0.142\nsamples = 26\nvalue = [2, 24]'),
#  Text(0.18980461289848685, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.19450565594241223, 0.375, 'gini = 0.0\nsamples = 24\nvalue = [0, 24]'),
#  Text(0.19685617746437492, 0.425, 'gini = 0.0\nsamples = 275\nvalue = [0, 275]'),
#  Text(0.19450565594241223, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1886293521375055, 0.675, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.24092845600117527, 0.725, 'x[19] <= -0.298\ngini = 0.418\nsamples = 188\nvalue = [56, 132]'),
#  Text(0.22741295724988983, 0.675, 'x[14] <= -0.966\ngini = 0.488\nsamples = 83\nvalue = [48, 35]'),
#  Text(0.21566034964007638, 0.625, 'x[7] <= 1.689\ngini = 0.394\nsamples = 63\nvalue = [46, 17]'),
#  Text(0.20625826355222565, 0.575, 'x[12] <= 3.066\ngini = 0.231\nsamples = 45\nvalue = [39, 6]'),
#  Text(0.20155722050830027, 0.525, 'x[18] <= 2.645\ngini = 0.054\nsamples = 36\nvalue = [35, 1]'),
#  Text(0.19920669898633758, 0.475, 'gini = 0.0\nsamples = 35\nvalue = [35, 0]'),
#  Text(0.20390774203026296, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.21095930659615103, 0.525, 'x[2] <= 10.464\ngini = 0.494\nsamples = 9\nvalue = [4, 5]'),
#  Text(0.20860878507418834, 0.475, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.21330982811811372, 0.475, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.22506243572792714, 0.575, 'x[2] <= 11.035\ngini = 0.475\nsamples = 18\nvalue = [7, 11]'),
#  Text(0.22036139268400176, 0.525, 'x[2] <= 6.171\ngini = 0.165\nsamples = 11\nvalue = [1, 10]'),
#  Text(0.21801087116203907, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.22271191420596445, 0.475, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.2297634787718525, 0.525, 'x[8] <= -4.082\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.22741295724988983, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.23211400029381518, 0.475, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.23916556485970325, 0.625, 'x[11] <= 6.583\ngini = 0.18\nsamples = 20\nvalue = [2, 18]'),
#  Text(0.23681504333774056, 0.575, 'x[8] <= 1.484\ngini = 0.1\nsamples = 19\nvalue = [1, 18]'),
#  Text(0.23446452181577787, 0.525, 'gini = 0.0\nsamples = 18\nvalue = [0, 18]'),
#  Text(0.23916556485970325, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.24151608638166594, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2544439547524607, 0.675, 'x[7] <= -1.217\ngini = 0.141\nsamples = 105\nvalue = [8, 97]'),
#  Text(0.24856765094755398, 0.625, 'x[0] <= -3.935\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.2462171294255913, 0.575, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.2509181724695167, 0.575, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.2603202585573674, 0.625, 'x[19] <= 0.284\ngini = 0.078\nsamples = 98\nvalue = [4, 94]'),
#  Text(0.255619215513442, 0.575, 'x[12] <= 0.239\ngini = 0.42\nsamples = 10\nvalue = [3, 7]'),
#  Text(0.25326869399147933, 0.525, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.2579697370354047, 0.525, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.2650213016012928, 0.575, 'x[10] <= -4.023\ngini = 0.022\nsamples = 88\nvalue = [1, 87]'),
#  Text(0.2626707800793301, 0.525, 'x[14] <= 0.063\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2603202585573674, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2650213016012928, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.26737182312325547, 0.525, 'gini = 0.0\nsamples = 86\nvalue = [0, 86]'),
#  Text(0.4737815851329514, 0.875, 'x[14] <= 0.759\ngini = 0.354\nsamples = 2767\nvalue = [2130, 637]'),
#  Text(0.36339429998530925, 0.825, 'x[2] <= -3.226\ngini = 0.246\nsamples = 1936\nvalue = [1658, 278]'),
#  Text(0.2814749522550316, 0.775, 'x[12] <= -2.049\ngini = 0.485\nsamples = 135\nvalue = [56, 79]'),
#  Text(0.27207286616718085, 0.725, 'x[10] <= -1.958\ngini = 0.32\nsamples = 55\nvalue = [44, 11]'),
#  Text(0.26737182312325547, 0.675, 'x[3] <= -2.211\ngini = 0.375\nsamples = 12\nvalue = [3, 9]'),
#  Text(0.2650213016012928, 0.625, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.26972234464521816, 0.625, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.27677390921110623, 0.675, 'x[0] <= -3.086\ngini = 0.089\nsamples = 43\nvalue = [41, 2]'),
#  Text(0.27442338768914354, 0.625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.2791244307330689, 0.625, 'gini = 0.0\nsamples = 41\nvalue = [41, 0]'),
#  Text(0.2908770383428823, 0.725, 'x[13] <= -3.054\ngini = 0.255\nsamples = 80\nvalue = [12, 68]'),
#  Text(0.28617599529895693, 0.675, 'x[19] <= 2.706\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.2838254737769943, 0.625, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.2885265168209196, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2955780813868077, 0.675, 'x[3] <= -2.924\ngini = 0.151\nsamples = 73\nvalue = [6, 67]'),
#  Text(0.293227559864845, 0.625, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.2979286029087704, 0.625, 'x[8] <= -4.843\ngini = 0.082\nsamples = 70\nvalue = [3, 67]'),
#  Text(0.2955780813868077, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.30027912443073307, 0.575, 'x[14] <= 0.661\ngini = 0.056\nsamples = 69\nvalue = [2, 67]'),
#  Text(0.2979286029087704, 0.525, 'x[4] <= 3.372\ngini = 0.029\nsamples = 68\nvalue = [1, 67]'),
#  Text(0.2955780813868077, 0.475, 'gini = 0.0\nsamples = 65\nvalue = [0, 65]'),
#  Text(0.30027912443073307, 0.475, 'x[5] <= 1.184\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.2979286029087704, 0.425, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.30262964595269576, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.30262964595269576, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4453136477155869, 0.775, 'x[10] <= -0.415\ngini = 0.197\nsamples = 1801\nvalue = [1602, 199]'),
#  Text(0.38835022770677247, 0.725, 'x[3] <= -0.873\ngini = 0.282\nsamples = 960\nvalue = [797, 163]'),
#  Text(0.3430292346114294, 0.675, 'x[2] <= 0.643\ngini = 0.181\nsamples = 697\nvalue = [627, 70]'),
#  Text(0.3214338181283972, 0.625, 'x[18] <= -1.557\ngini = 0.414\nsamples = 89\nvalue = [63, 26]'),
#  Text(0.3143822535625092, 0.575, 'x[4] <= 4.616\ngini = 0.124\nsamples = 45\nvalue = [42, 3]'),
#  Text(0.3120317320405465, 0.525, 'x[19] <= 1.316\ngini = 0.087\nsamples = 44\nvalue = [42, 2]'),
#  Text(0.3096812105185838, 0.475, 'x[10] <= -4.138\ngini = 0.045\nsamples = 43\nvalue = [42, 1]'),
#  Text(0.30733068899662114, 0.425, 'x[9] <= 3.902\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.30498016747465845, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3096812105185838, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3120317320405465, 0.425, 'gini = 0.0\nsamples = 40\nvalue = [40, 0]'),
#  Text(0.3143822535625092, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.31673277508447184, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3284853826942853, 0.575, 'x[9] <= 2.329\ngini = 0.499\nsamples = 44\nvalue = [21, 23]'),
#  Text(0.3214338181283972, 0.525, 'x[1] <= 0.402\ngini = 0.298\nsamples = 22\nvalue = [4, 18]'),
#  Text(0.31908329660643453, 0.475, 'gini = 0.0\nsamples = 17\nvalue = [0, 17]'),
#  Text(0.3237843396503599, 0.475, 'x[10] <= -1.711\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.3214338181283972, 0.425, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.3261348611723226, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.33553694726017336, 0.525, 'x[18] <= 1.145\ngini = 0.351\nsamples = 22\nvalue = [17, 5]'),
#  Text(0.33318642573821067, 0.475, 'x[8] <= 1.555\ngini = 0.105\nsamples = 18\nvalue = [17, 1]'),
#  Text(0.330835904216248, 0.425, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.33553694726017336, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.33788746878213605, 0.475, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.36462465109446157, 0.625, 'x[4] <= -0.421\ngini = 0.134\nsamples = 608\nvalue = [564, 44]'),
#  Text(0.35199059791391213, 0.575, 'x[11] <= -13.633\ngini = 0.084\nsamples = 480\nvalue = [459, 21]'),
#  Text(0.34964007639194944, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3543411194358748, 0.525, 'x[0] <= 4.801\ngini = 0.08\nsamples = 479\nvalue = [459, 20]'),
#  Text(0.35199059791391213, 0.475, 'x[0] <= 1.576\ngini = 0.076\nsamples = 478\nvalue = [459, 19]'),
#  Text(0.34023799030409874, 0.425, 'x[9] <= -0.621\ngini = 0.054\nsamples = 431\nvalue = [419, 12]'),
#  Text(0.33788746878213605, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3425885118260614, 0.375, 'x[3] <= -1.423\ngini = 0.05\nsamples = 430\nvalue = [419, 11]'),
#  Text(0.33318642573821067, 0.325, 'x[18] <= 2.561\ngini = 0.022\nsamples = 362\nvalue = [358, 4]'),
#  Text(0.3284853826942853, 0.275, 'x[17] <= -1.639\ngini = 0.011\nsamples = 348\nvalue = [346, 2]'),
#  Text(0.3261348611723226, 0.225, 'x[2] <= 12.412\ngini = 0.121\nsamples = 31\nvalue = [29, 2]'),
#  Text(0.3237843396503599, 0.175, 'x[10] <= -4.242\ngini = 0.064\nsamples = 30\nvalue = [29, 1]'),
#  Text(0.3214338181283972, 0.125, 'x[10] <= -4.464\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.31908329660643453, 0.075, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.3237843396503599, 0.075, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3261348611723226, 0.125, 'gini = 0.0\nsamples = 25\nvalue = [25, 0]'),
#  Text(0.3284853826942853, 0.175, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.330835904216248, 0.225, 'gini = 0.0\nsamples = 317\nvalue = [317, 0]'),
#  Text(0.33788746878213605, 0.275, 'x[11] <= 2.861\ngini = 0.245\nsamples = 14\nvalue = [12, 2]'),
#  Text(0.33553694726017336, 0.225, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.34023799030409874, 0.225, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.35199059791391213, 0.325, 'x[13] <= 3.485\ngini = 0.185\nsamples = 68\nvalue = [61, 7]'),
#  Text(0.3472895548699868, 0.275, 'x[1] <= -4.739\ngini = 0.073\nsamples = 53\nvalue = [51, 2]'),
#  Text(0.3449390333480241, 0.225, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.34964007639194944, 0.225, 'x[9] <= -0.321\ngini = 0.038\nsamples = 52\nvalue = [51, 1]'),
#  Text(0.3472895548699868, 0.175, 'x[19] <= 0.282\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.3449390333480241, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.34964007639194944, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.35199059791391213, 0.175, 'gini = 0.0\nsamples = 50\nvalue = [50, 0]'),
#  Text(0.3566916409578375, 0.275, 'x[19] <= -3.01\ngini = 0.444\nsamples = 15\nvalue = [10, 5]'),
#  Text(0.3543411194358748, 0.225, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.3590421624798002, 0.225, 'x[1] <= -1.548\ngini = 0.278\nsamples = 12\nvalue = [10, 2]'),
#  Text(0.3566916409578375, 0.175, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.3613926840017629, 0.175, 'x[3] <= -1.073\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.3590421624798002, 0.125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3637432055237256, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3637432055237256, 0.425, 'x[10] <= -0.935\ngini = 0.254\nsamples = 47\nvalue = [40, 7]'),
#  Text(0.3613926840017629, 0.375, 'x[14] <= -0.214\ngini = 0.165\nsamples = 44\nvalue = [40, 4]'),
#  Text(0.3590421624798002, 0.325, 'gini = 0.0\nsamples = 32\nvalue = [32, 0]'),
#  Text(0.3637432055237256, 0.325, 'x[8] <= -1.963\ngini = 0.444\nsamples = 12\nvalue = [8, 4]'),
#  Text(0.3613926840017629, 0.275, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.36609372704568827, 0.275, 'x[17] <= -3.323\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.3637432055237256, 0.225, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.36844424856765096, 0.225, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.36609372704568827, 0.375, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.3566916409578375, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.377258704275011, 0.575, 'x[9] <= -0.178\ngini = 0.295\nsamples = 128\nvalue = [105, 23]'),
#  Text(0.36844424856765096, 0.525, 'x[16] <= -6.107\ngini = 0.42\nsamples = 10\nvalue = [3, 7]'),
#  Text(0.36609372704568827, 0.475, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.37079477008961365, 0.475, 'x[11] <= -0.332\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.36844424856765096, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.37314529161157634, 0.425, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.3860731599823711, 0.525, 'x[19] <= 1.863\ngini = 0.234\nsamples = 118\nvalue = [102, 16]'),
#  Text(0.3837226384604084, 0.475, 'x[0] <= 0.012\ngini = 0.201\nsamples = 115\nvalue = [102, 13]'),
#  Text(0.3778463346555017, 0.425, 'x[4] <= 5.671\ngini = 0.064\nsamples = 90\nvalue = [87, 3]'),
#  Text(0.375495813133539, 0.375, 'x[13] <= 10.776\ngini = 0.044\nsamples = 89\nvalue = [87, 2]'),
#  Text(0.37314529161157634, 0.325, 'x[14] <= 0.445\ngini = 0.022\nsamples = 88\nvalue = [87, 1]'),
#  Text(0.37079477008961365, 0.275, 'gini = 0.0\nsamples = 85\nvalue = [85, 0]'),
#  Text(0.375495813133539, 0.275, 'x[1] <= -0.829\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.37314529161157634, 0.225, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3778463346555017, 0.225, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3778463346555017, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.38019685617746435, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3895989422653151, 0.425, 'x[1] <= -1.62\ngini = 0.48\nsamples = 25\nvalue = [15, 10]'),
#  Text(0.3848978992213897, 0.375, 'x[11] <= 6.395\ngini = 0.18\nsamples = 10\nvalue = [1, 9]'),
#  Text(0.38254737769942704, 0.325, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.3872484207433524, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3942999853092405, 0.375, 'x[10] <= -0.668\ngini = 0.124\nsamples = 15\nvalue = [14, 1]'),
#  Text(0.3919494637872778, 0.325, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.3966505068312032, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.38842368150433376, 0.475, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.43367122080211545, 0.675, 'x[17] <= 2.151\ngini = 0.457\nsamples = 263\nvalue = [170, 93]'),
#  Text(0.416629939767886, 0.625, 'x[5] <= -1.389\ngini = 0.406\nsamples = 226\nvalue = [162, 64]'),
#  Text(0.40370207139709124, 0.575, 'x[15] <= 2.84\ngini = 0.417\nsamples = 27\nvalue = [8, 19]'),
#  Text(0.39900102835316587, 0.525, 'x[4] <= -2.354\ngini = 0.245\nsamples = 21\nvalue = [3, 18]'),
#  Text(0.3966505068312032, 0.475, 'x[13] <= 5.858\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.3942999853092405, 0.425, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.39900102835316587, 0.425, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.40135154987512855, 0.475, 'gini = 0.0\nsamples = 15\nvalue = [0, 15]'),
#  Text(0.4084031144410166, 0.525, 'x[18] <= -3.695\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.40605259291905393, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4107536359629793, 0.475, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.4295578081386808, 0.575, 'x[17] <= -0.032\ngini = 0.35\nsamples = 199\nvalue = [154, 45]'),
#  Text(0.42015572205083, 0.525, 'x[7] <= 2.64\ngini = 0.223\nsamples = 125\nvalue = [109, 16]'),
#  Text(0.41545467900690464, 0.475, 'x[11] <= -4.426\ngini = 0.176\nsamples = 113\nvalue = [102, 11]'),
#  Text(0.41310415748494195, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4178052005288673, 0.425, 'x[19] <= -4.482\ngini = 0.163\nsamples = 112\nvalue = [102, 10]'),
#  Text(0.41545467900690464, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.42015572205083, 0.375, 'x[19] <= 3.566\ngini = 0.149\nsamples = 111\nvalue = [102, 9]'),
#  Text(0.4178052005288673, 0.325, 'x[16] <= -0.447\ngini = 0.135\nsamples = 110\nvalue = [102, 8]'),
#  Text(0.41545467900690464, 0.275, 'x[8] <= -1.579\ngini = 0.234\nsamples = 59\nvalue = [51, 8]'),
#  Text(0.40957837520199797, 0.225, 'x[9] <= 3.656\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.4072278536800353, 0.175, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.4119288967239606, 0.175, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.42133098281181136, 0.225, 'x[2] <= -1.629\ngini = 0.109\nsamples = 52\nvalue = [49, 3]'),
#  Text(0.416629939767886, 0.175, 'x[19] <= -2.455\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.4142794182459233, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.41898046128984867, 0.125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.42603202585573674, 0.175, 'x[1] <= -2.885\ngini = 0.04\nsamples = 49\nvalue = [48, 1]'),
#  Text(0.42368150433377405, 0.125, 'x[9] <= 2.73\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.42133098281181136, 0.075, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.42603202585573674, 0.075, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.42838254737769943, 0.125, 'gini = 0.0\nsamples = 47\nvalue = [47, 0]'),
#  Text(0.42015572205083, 0.275, 'gini = 0.0\nsamples = 51\nvalue = [51, 0]'),
#  Text(0.4225062435727927, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4248567650947554, 0.475, 'x[19] <= -2.027\ngini = 0.486\nsamples = 12\nvalue = [7, 5]'),
#  Text(0.4225062435727927, 0.425, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.4272072866167181, 0.425, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.43895989422653153, 0.525, 'x[0] <= -1.257\ngini = 0.477\nsamples = 74\nvalue = [45, 29]'),
#  Text(0.43425885118260615, 0.475, 'x[10] <= -0.508\ngini = 0.17\nsamples = 32\nvalue = [29, 3]'),
#  Text(0.43190832966064346, 0.425, 'x[7] <= -2.471\ngini = 0.064\nsamples = 30\nvalue = [29, 1]'),
#  Text(0.4295578081386808, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.43425885118260615, 0.375, 'gini = 0.0\nsamples = 29\nvalue = [29, 0]'),
#  Text(0.43660937270456884, 0.425, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.44366093727045686, 0.475, 'x[12] <= -0.253\ngini = 0.472\nsamples = 42\nvalue = [16, 26]'),
#  Text(0.4413104157484942, 0.425, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.44601145879241955, 0.425, 'x[14] <= -4.069\ngini = 0.36\nsamples = 34\nvalue = [8, 26]'),
#  Text(0.44366093727045686, 0.375, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.44836198031438224, 0.375, 'x[15] <= 2.392\ngini = 0.271\nsamples = 31\nvalue = [5, 26]'),
#  Text(0.44366093727045686, 0.325, 'x[7] <= 3.751\ngini = 0.074\nsamples = 26\nvalue = [1, 25]'),
#  Text(0.4413104157484942, 0.275, 'gini = 0.0\nsamples = 25\nvalue = [0, 25]'),
#  Text(0.44601145879241955, 0.275, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4530630233583076, 0.325, 'x[16] <= -6.124\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.4507125018363449, 0.275, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4554135448802703, 0.275, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.4507125018363449, 0.625, 'x[19] <= -1.444\ngini = 0.339\nsamples = 37\nvalue = [8, 29]'),
#  Text(0.44601145879241955, 0.575, 'x[12] <= 1.671\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.44366093727045686, 0.525, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.44836198031438224, 0.525, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.4554135448802703, 0.575, 'x[10] <= -1.194\ngini = 0.18\nsamples = 30\nvalue = [3, 27]'),
#  Text(0.4530630233583076, 0.525, 'gini = 0.0\nsamples = 23\nvalue = [0, 23]'),
#  Text(0.457764066402233, 0.525, 'x[1] <= -1.814\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.4554135448802703, 0.475, 'x[0] <= -1.227\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.4530630233583076, 0.425, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.457764066402233, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4601145879241957, 0.475, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.5022770677244014, 0.725, 'x[19] <= 2.793\ngini = 0.082\nsamples = 841\nvalue = [805, 36]'),
#  Text(0.494050242397532, 0.675, 'x[7] <= -5.888\ngini = 0.07\nsamples = 830\nvalue = [800, 30]'),
#  Text(0.4893491993536066, 0.625, 'x[19] <= -1.395\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.4869986778316439, 0.575, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.4916997208755693, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4987512854414573, 0.625, 'x[12] <= 6.667\ngini = 0.063\nsamples = 826\nvalue = [799, 27]'),
#  Text(0.4964007639194946, 0.575, 'x[7] <= 6.141\ngini = 0.061\nsamples = 825\nvalue = [799, 26]'),
#  Text(0.494050242397532, 0.525, 'x[6] <= 10.866\ngini = 0.059\nsamples = 824\nvalue = [799, 25]'),
#  Text(0.4916997208755693, 0.475, 'x[18] <= 2.241\ngini = 0.057\nsamples = 823\nvalue = [799, 24]'),
#  Text(0.4774496841486705, 0.425, 'x[11] <= -0.758\ngini = 0.045\nsamples = 784\nvalue = [766, 18]'),
#  Text(0.46716615249008375, 0.375, 'x[19] <= 1.255\ngini = 0.117\nsamples = 209\nvalue = [196, 13]'),
#  Text(0.4624651094461584, 0.325, 'x[11] <= -0.763\ngini = 0.085\nsamples = 202\nvalue = [193, 9]'),
#  Text(0.4601145879241957, 0.275, 'x[19] <= -2.004\ngini = 0.076\nsamples = 201\nvalue = [193, 8]'),
#  Text(0.457764066402233, 0.225, 'gini = 0.0\nsamples = 118\nvalue = [118, 0]'),
#  Text(0.4624651094461584, 0.225, 'x[18] <= -1.336\ngini = 0.174\nsamples = 83\nvalue = [75, 8]'),
#  Text(0.4601145879241957, 0.175, 'gini = 0.0\nsamples = 49\nvalue = [49, 0]'),
#  Text(0.46481563096812106, 0.175, 'x[17] <= 0.981\ngini = 0.36\nsamples = 34\nvalue = [26, 8]'),
#  Text(0.4624651094461584, 0.125, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]'),
#  Text(0.46716615249008375, 0.125, 'x[4] <= -2.733\ngini = 0.498\nsamples = 15\nvalue = [7, 8]'),
#  Text(0.4624651094461584, 0.075, 'x[3] <= -0.354\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.4601145879241957, 0.025, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.46481563096812106, 0.025, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.47186719553400913, 0.075, 'x[13] <= 5.282\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.46951667401204644, 0.025, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.4742177170559718, 0.025, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.46481563096812106, 0.275, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.47186719553400913, 0.325, 'x[12] <= -1.213\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.46951667401204644, 0.275, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.4742177170559718, 0.275, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.48773321580725726, 0.375, 'x[2] <= -2.543\ngini = 0.017\nsamples = 575\nvalue = [570, 5]'),
#  Text(0.48126928162185983, 0.325, 'x[15] <= 4.113\ngini = 0.298\nsamples = 11\nvalue = [9, 2]'),
#  Text(0.47891876009989715, 0.275, 'x[10] <= 0.204\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.47656823857793446, 0.225, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.48126928162185983, 0.225, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.4836198031438225, 0.275, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4941971499926546, 0.325, 'x[7] <= -4.75\ngini = 0.011\nsamples = 564\nvalue = [561, 3]'),
#  Text(0.4883208461877479, 0.275, 'x[9] <= 0.646\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.4859703246657852, 0.225, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4906713677097106, 0.225, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5000734537975613, 0.275, 'x[8] <= -6.028\ngini = 0.007\nsamples = 562\nvalue = [560, 2]'),
#  Text(0.49537241075363597, 0.225, 'x[3] <= -0.057\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.4930218892316733, 0.175, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.49772293227559866, 0.175, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5047744968414867, 0.225, 'x[19] <= 1.664\ngini = 0.004\nsamples = 552\nvalue = [551, 1]'),
#  Text(0.502423975319524, 0.175, 'gini = 0.0\nsamples = 530\nvalue = [530, 0]'),
#  Text(0.5071250183634494, 0.175, 'x[5] <= -0.359\ngini = 0.087\nsamples = 22\nvalue = [21, 1]'),
#  Text(0.5047744968414867, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.509475539885412, 0.125, 'gini = 0.0\nsamples = 21\nvalue = [21, 0]'),
#  Text(0.5059497576024681, 0.425, 'x[14] <= 0.096\ngini = 0.26\nsamples = 39\nvalue = [33, 6]'),
#  Text(0.5012487145585427, 0.375, 'x[1] <= 1.539\ngini = 0.111\nsamples = 34\nvalue = [32, 2]'),
#  Text(0.49889819303658, 0.325, 'gini = 0.0\nsamples = 32\nvalue = [32, 0]'),
#  Text(0.5035992360805054, 0.325, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5106508006463935, 0.375, 'x[10] <= 2.888\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.5083002791244308, 0.325, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.5130013221683561, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4964007639194946, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4987512854414573, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.50110180696342, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5105038930512708, 0.675, 'x[10] <= 1.859\ngini = 0.496\nsamples = 11\nvalue = [5, 6]'),
#  Text(0.5081533715293081, 0.625, 'x[7] <= -4.307\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.5058028500073454, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5105038930512708, 0.575, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.5128544145732334, 0.625, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.5841688702805935, 0.825, 'x[16] <= -1.085\ngini = 0.491\nsamples = 831\nvalue = [472, 359]'),
#  Text(0.5513442044953724, 0.775, 'x[15] <= 0.594\ngini = 0.394\nsamples = 378\nvalue = [102, 276]'),
#  Text(0.5343029234611429, 0.725, 'x[12] <= -0.921\ngini = 0.217\nsamples = 267\nvalue = [33, 234]'),
#  Text(0.5284266196562363, 0.675, 'x[19] <= -0.24\ngini = 0.415\nsamples = 17\nvalue = [12, 5]'),
#  Text(0.5260760981342736, 0.625, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.530777141178199, 0.625, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.5401792272660496, 0.675, 'x[5] <= 4.151\ngini = 0.154\nsamples = 250\nvalue = [21, 229]'),
#  Text(0.5354781842221242, 0.625, 'x[18] <= -4.388\ngini = 0.123\nsamples = 244\nvalue = [16, 228]'),
#  Text(0.5331276627001617, 0.575, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5378287057440869, 0.575, 'x[17] <= -5.077\ngini = 0.109\nsamples = 242\nvalue = [14, 228]'),
#  Text(0.5354781842221242, 0.525, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5401792272660496, 0.525, 'x[2] <= 8.874\ngini = 0.095\nsamples = 240\nvalue = [12, 228]'),
#  Text(0.5332745702952842, 0.475, 'x[15] <= 0.582\ngini = 0.052\nsamples = 223\nvalue = [6, 217]'),
#  Text(0.5265168209196416, 0.425, 'x[3] <= -3.588\ngini = 0.044\nsamples = 221\nvalue = [5, 216]'),
#  Text(0.5200528867342442, 0.375, 'x[18] <= -1.463\ngini = 0.245\nsamples = 14\nvalue = [2, 12]'),
#  Text(0.5177023652122815, 0.325, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5224034082562068, 0.325, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.532980755105039, 0.375, 'x[15] <= -6.615\ngini = 0.029\nsamples = 207\nvalue = [3, 204]'),
#  Text(0.5271044513001322, 0.325, 'x[15] <= -6.894\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.5247539297781695, 0.275, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.5294549728220949, 0.275, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5388570589099456, 0.325, 'x[1] <= 4.96\ngini = 0.02\nsamples = 203\nvalue = [2, 201]'),
#  Text(0.5341560158660202, 0.275, 'x[17] <= -3.443\ngini = 0.01\nsamples = 198\nvalue = [1, 197]'),
#  Text(0.5318054943440575, 0.225, 'x[11] <= 0.667\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.5294549728220949, 0.175, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5341560158660202, 0.175, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.5365065373879829, 0.225, 'gini = 0.0\nsamples = 190\nvalue = [0, 190]'),
#  Text(0.543558101953871, 0.275, 'x[16] <= -7.979\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.5412075804319083, 0.225, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5459086234758337, 0.225, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.540032319670927, 0.425, 'x[19] <= -1.019\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5376817981489643, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5423828411928897, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5470838842368151, 0.475, 'x[14] <= 2.016\ngini = 0.457\nsamples = 17\nvalue = [6, 11]'),
#  Text(0.5447333627148524, 0.425, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.5494344057587778, 0.425, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.544880270309975, 0.625, 'x[18] <= 2.52\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.5425297487880123, 0.575, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.5472307918319377, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5683854855296019, 0.725, 'x[19] <= -2.664\ngini = 0.47\nsamples = 111\nvalue = [69, 42]'),
#  Text(0.5589833994417511, 0.675, 'x[7] <= 1.451\ngini = 0.389\nsamples = 34\nvalue = [9, 25]'),
#  Text(0.5542823563978257, 0.625, 'x[13] <= -3.331\ngini = 0.147\nsamples = 25\nvalue = [2, 23]'),
#  Text(0.5519318348758631, 0.575, 'x[14] <= 3.794\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.5495813133539004, 0.525, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5542823563978257, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5566328779197884, 0.575, 'gini = 0.0\nsamples = 22\nvalue = [0, 22]'),
#  Text(0.5636844424856765, 0.625, 'x[19] <= -4.279\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.5613339209637138, 0.575, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5660349640076392, 0.575, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.5777875716174526, 0.675, 'x[17] <= 0.471\ngini = 0.344\nsamples = 77\nvalue = [60, 17]'),
#  Text(0.5730865285735273, 0.625, 'x[7] <= -3.536\ngini = 0.216\nsamples = 65\nvalue = [57, 8]'),
#  Text(0.5707360070515646, 0.575, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.57543705009549, 0.575, 'x[14] <= 5.561\ngini = 0.148\nsamples = 62\nvalue = [57, 5]'),
#  Text(0.5730865285735273, 0.525, 'x[9] <= 7.187\ngini = 0.095\nsamples = 60\nvalue = [57, 3]'),
#  Text(0.5707360070515646, 0.475, 'x[18] <= -2.999\ngini = 0.065\nsamples = 59\nvalue = [57, 2]'),
#  Text(0.5660349640076392, 0.425, 'x[0] <= -1.961\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5636844424856765, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5683854855296019, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.57543705009549, 0.425, 'x[6] <= -3.998\ngini = 0.034\nsamples = 57\nvalue = [56, 1]'),
#  Text(0.5730865285735273, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5777875716174526, 0.375, 'gini = 0.0\nsamples = 56\nvalue = [56, 0]'),
#  Text(0.57543705009549, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5777875716174526, 0.525, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.582488614661378, 0.625, 'x[7] <= 1.915\ngini = 0.375\nsamples = 12\nvalue = [3, 9]'),
#  Text(0.5801380931394153, 0.575, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.5848391361833407, 0.575, 'x[12] <= 1.296\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.582488614661378, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5871896577053034, 0.525, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.6169935360658146, 0.775, 'x[7] <= -0.124\ngini = 0.299\nsamples = 453\nvalue = [370, 83]'),
#  Text(0.5965550168943734, 0.725, 'x[11] <= -3.21\ngini = 0.177\nsamples = 377\nvalue = [340, 37]'),
#  Text(0.5895401792272661, 0.675, 'x[16] <= 6.008\ngini = 0.465\nsamples = 19\nvalue = [7, 12]'),
#  Text(0.5871896577053034, 0.625, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.5918907007492288, 0.625, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.6035698545614808, 0.675, 'x[5] <= -2.46\ngini = 0.13\nsamples = 358\nvalue = [333, 25]'),
#  Text(0.5965917437931542, 0.625, 'x[0] <= -1.511\ngini = 0.483\nsamples = 22\nvalue = [13, 9]'),
#  Text(0.5942412222711915, 0.575, 'x[7] <= -1.378\ngini = 0.375\nsamples = 12\nvalue = [3, 9]'),
#  Text(0.5918907007492288, 0.525, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.5965917437931542, 0.525, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.5989422653151167, 0.575, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.6105479653298076, 0.625, 'x[16] <= -0.676\ngini = 0.091\nsamples = 336\nvalue = [320, 16]'),
#  Text(0.6036433083590421, 0.575, 'x[3] <= -0.653\ngini = 0.48\nsamples = 15\nvalue = [9, 6]'),
#  Text(0.6012927868370794, 0.525, 'x[14] <= 2.613\ngini = 0.298\nsamples = 11\nvalue = [9, 2]'),
#  Text(0.5989422653151167, 0.475, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.6036433083590421, 0.475, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6059938298810048, 0.525, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.617452622300573, 0.575, 'x[6] <= 11.442\ngini = 0.06\nsamples = 321\nvalue = [311, 10]'),
#  Text(0.6151021007786103, 0.525, 'x[2] <= 12.475\ngini = 0.055\nsamples = 320\nvalue = [311, 9]'),
#  Text(0.6083443514029675, 0.475, 'x[0] <= -5.563\ngini = 0.044\nsamples = 314\nvalue = [307, 7]'),
#  Text(0.6018804172175701, 0.425, 'x[11] <= 2.809\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.5995298956956074, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6042309387395328, 0.375, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.6148082855883649, 0.425, 'x[16] <= 0.407\ngini = 0.032\nsamples = 304\nvalue = [299, 5]'),
# ...
#  Text(0.9059791391214925, 0.625, 'x[10] <= -2.111\ngini = 0.375\nsamples = 24\nvalue = [18, 6]'),
#  Text(0.90362861759953, 0.575, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.9083296606434552, 0.575, 'x[9] <= -0.165\ngini = 0.245\nsamples = 21\nvalue = [18, 3]'),
#  Text(0.9059791391214925, 0.525, 'x[19] <= -0.905\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.90362861759953, 0.475, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9083296606434552, 0.475, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.9106801821654179, 0.525, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(0.9294843543411194, 0.625, 'x[7] <= 0.602\ngini = 0.037\nsamples = 370\nvalue = [363, 7]'),
#  Text(0.9200822682532687, 0.575, 'x[13] <= 4.758\ngini = 0.012\nsamples = 330\nvalue = [328, 2]'),
#  Text(0.9153812252093433, 0.525, 'x[3] <= 0.583\ngini = 0.006\nsamples = 317\nvalue = [316, 1]'),
#  Text(0.9130307036873806, 0.475, 'x[3] <= 0.582\ngini = 0.111\nsamples = 17\nvalue = [16, 1]'),
#  Text(0.9106801821654179, 0.425, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(0.9153812252093433, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.917731746731306, 0.475, 'gini = 0.0\nsamples = 300\nvalue = [300, 0]'),
#  Text(0.924783311297194, 0.525, 'x[0] <= -3.599\ngini = 0.142\nsamples = 13\nvalue = [12, 1]'),
#  Text(0.9224327897752314, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9271338328191567, 0.475, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.9388864404289702, 0.575, 'x[5] <= 0.315\ngini = 0.219\nsamples = 40\nvalue = [35, 5]'),
#  Text(0.9341853973850448, 0.525, 'x[14] <= 0.169\ngini = 0.5\nsamples = 8\nvalue = [4, 4]'),
#  Text(0.9318348758630821, 0.475, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.9365359189070075, 0.475, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.9435874834728956, 0.525, 'x[6] <= -1.07\ngini = 0.061\nsamples = 32\nvalue = [31, 1]'),
#  Text(0.9412369619509329, 0.475, 'x[11] <= 6.067\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.9388864404289702, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9435874834728956, 0.425, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9459380049948583, 0.475, 'gini = 0.0\nsamples = 29\nvalue = [29, 0]'),
#  Text(0.9224327897752314, 0.675, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9529895695607463, 0.725, 'x[4] <= -0.414\ngini = 0.408\nsamples = 63\nvalue = [45, 18]'),
#  Text(0.9459380049948583, 0.675, 'x[2] <= -2.691\ngini = 0.423\nsamples = 23\nvalue = [7, 16]'),
#  Text(0.9435874834728956, 0.625, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.9482885265168209, 0.625, 'x[7] <= 0.785\ngini = 0.266\nsamples = 19\nvalue = [3, 16]'),
#  Text(0.9459380049948583, 0.575, 'gini = 0.0\nsamples = 15\nvalue = [0, 15]'),
#  Text(0.9506390480387836, 0.575, 'x[18] <= 1.11\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.9482885265168209, 0.525, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.9529895695607463, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9600411341266344, 0.675, 'x[8] <= 2.992\ngini = 0.095\nsamples = 40\nvalue = [38, 2]'),
#  Text(0.9576906126046717, 0.625, 'x[1] <= 0.697\ngini = 0.05\nsamples = 39\nvalue = [38, 1]'),
#  Text(0.955340091082709, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9600411341266344, 0.575, 'gini = 0.0\nsamples = 38\nvalue = [38, 0]'),
#  Text(0.9623916556485971, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.969443220214485, 0.775, 'x[5] <= 2.849\ngini = 0.216\nsamples = 65\nvalue = [8, 57]'),
#  Text(0.9670926986925225, 0.725, 'x[7] <= 1.476\ngini = 0.034\nsamples = 58\nvalue = [1, 57]'),
#  Text(0.9647421771705598, 0.675, 'gini = 0.0\nsamples = 57\nvalue = [0, 57]'),
#  Text(0.969443220214485, 0.675, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9717937417364477, 0.725, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.9870721316292053, 0.825, 'x[8] <= -2.078\ngini = 0.291\nsamples = 130\nvalue = [23, 107]'),
#  Text(0.9811958278242985, 0.775, 'x[10] <= 2.103\ngini = 0.129\nsamples = 101\nvalue = [7, 94]'),
#  Text(0.9764947847803731, 0.725, 'x[0] <= 3.853\ngini = 0.043\nsamples = 91\nvalue = [2, 89]'),
#  Text(0.9741442632584104, 0.675, 'x[10] <= -3.786\ngini = 0.022\nsamples = 90\nvalue = [1, 89]'),
#  Text(0.9717937417364477, 0.625, 'x[15] <= -3.552\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.969443220214485, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9741442632584104, 0.575, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.9764947847803731, 0.625, 'gini = 0.0\nsamples = 85\nvalue = [0, 85]'),
#  Text(0.9788453063023358, 0.675, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9858968708682239, 0.725, 'x[7] <= 2.875\ngini = 0.5\nsamples = 10\nvalue = [5, 5]'),
#  Text(0.9835463493462612, 0.675, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.9882473923901866, 0.675, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.9929484354341119, 0.775, 'x[14] <= 2.199\ngini = 0.495\nsamples = 29\nvalue = [16, 13]'),
#  Text(0.9905979139121492, 0.725, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.9952989569560746, 0.725, 'x[10] <= -4.936\ngini = 0.231\nsamples = 15\nvalue = [2, 13]'),
#  Text(0.9929484354341119, 0.675, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9976494784780373, 0.675, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]')]
# Error in callback <function flush_figures at 0x7c020c9dc3a0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/matplotlib_inline/backend_inline.py in flush_figures()
#     124             # ignore the tracking, just draw and close all figures
#     125             try:
# --> 126                 return show(True)
#     127             except Exception as e:
#     128                 # safely show traceback if in IPython, else raise
#
# /usr/local/lib/python3.10/dist-packages/matplotlib_inline/backend_inline.py in show(close, block)
#      88     try:
#      89         for figure_manager in Gcf.get_all_fig_managers():
# ---> 90             display(
#      91                 figure_manager.canvas.figure,
#      92                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     319         else:
# --> 320             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     321             if not format_dict:
#     322                 # nothing to display (e.g. _ipython_display_ took over)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-2> in __call__(self, obj)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2340                 )
#    2341                 with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2342                     self.figure.draw(renderer)
#    2343
#    2344             if bbox_inches:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      93     @wraps(draw)
#      94     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95         result = draw(artist, renderer, *args, **kwargs)
#      96         if renderer._rasterizing:
#      97             renderer.stop_rasterizing()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      70                 renderer.start_filter()
#      71
# ---> 72             return draw(artist, renderer)
#      73         finally:
#      74             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    3138
#    3139             self.patch.draw(renderer)
# -> 3140             mimage._draw_list_compositing_images(
#    3141                 renderer, self, artists, self.suppressComposite)
#    3142
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      70                 renderer.start_filter()
#      71
# ---> 72             return draw(artist, renderer)
#      73         finally:
#      74             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in draw(self, renderer)
#    3062             _draw_rasterized(self.figure, artists_rasterized, renderer)
#    3063
# -> 3064         mimage._draw_list_compositing_images(
#    3065             renderer, self, artists, self.figure.suppressComposite)
#    3066
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      70                 renderer.start_filter()
#      71
# ---> 72             return draw(artist, renderer)
#      73         finally:
#      74             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/text.py in draw(self, renderer)
#    2030             if self.arrow_patch.figure is None and self.figure is not None:
#    2031                 self.arrow_patch.figure = self.figure
# -> 2032             self.arrow_patch.draw(renderer)
#    2033         # Draw text, including FancyBboxPatch, after FancyArrowPatch.
#    2034         # Otherwise, a wedge arrowstyle can land partly on top of the Bbox.
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      37             renderer._rasterizing = False
#      38
# ---> 39         return draw(artist, renderer, *args, **kwargs)
#      40
#      41     draw_wrapper._supports_rasterization = False
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/patches.py in draw(self, renderer)
#    4350         # take a renderer argument, but get_path should be adapted too.
#    4351         self._dpi_cor = renderer.points_to_pixels(1.)
# -> 4352         path, fillable = self._get_path_in_displaycoord()
#    4353
#    4354         if not np.iterable(fillable):
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/patches.py in _get_path_in_displaycoord(self)
#    4325             posB = self._convert_xy_units(self._posA_posB[1])
#    4326             (posA, posB) = self.get_transform().transform((posA, posB))
# -> 4327             _path = self.get_connectionstyle()(posA, posB,
#    4328                                                patchA=self.patchA,
#    4329                                                patchB=self.patchB,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/patches.py in __call__(self, posA, posB, shrinkA, shrinkB, patchA, patchB)
#    2725             """
#    2726             path = self.connect(posA, posB)
# -> 2727             path = self._clip(
#    2728                 path,
#    2729                 self._in_patch(patchA) if patchA else None,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/patches.py in _clip(self, path, in_start, in_stop)
#    2708             if in_start:
#    2709                 try:
# -> 2710                     _, path = split_path_inout(path, in_start)
#    2711                 except ValueError:
#    2712                     pass
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/bezier.py in split_path_inout(path, inside, tolerance, reorder_inout)
#     368
#     369     bp = bezier_path.reshape((-1, 2))
# --> 370     left, right = split_bezier_intersecting_with_closedpath(
#     371         bp, inside, tolerance)
#     372     if len(left) == 2:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/bezier.py in split_bezier_intersecting_with_closedpath(bezier, inside_closedpath, tolerance)
#     331     bezier_point_at_t = bz.point_at_t
#     332
# --> 333     t0, t1 = find_bezier_t_intersecting_with_closedpath(
#     334         bezier_point_at_t, inside_closedpath, tolerance=tolerance)
#     335
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/bezier.py in find_bezier_t_intersecting_with_closedpath(bezier_point_at_t, inside_closedpath, t0, t1, tolerance)
#     168         middle_t = 0.5 * (t0 + t1)
#     169         middle = bezier_point_at_t(middle_t)
# --> 170         middle_inside = inside_closedpath(middle)
#     171
#     172         if start_inside ^ middle_inside:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/patches.py in <lambda>(xy)
#    2695             contained in *patch*.
#    2696             """
# -> 2697             return lambda xy: patch.contains(
#    2698                 SimpleNamespace(x=xy[0], y=xy[1]))[0]
#    2699
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/patches.py in contains(self, mouseevent, radius)
#     140         codes = self.get_path().codes
#     141         if codes is not None:
# --> 142             vertices = self.get_path().vertices
#     143             # if the current path is concatenated by multiple sub paths.
#     144             # get the indexes of the starting code(MOVETO) of all sub paths
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/patches.py in get_path(self)
#    3926         m_aspect = self.get_mutation_aspect()
#    3927         # Call boxstyle with y, height squeezed by aspect_ratio.
# -> 3928         path = boxstyle(self._x, self._y / m_aspect,
#    3929                         self._width, self._height / m_aspect,
#    3930                         self.get_mutation_scale())
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/patches.py in __call__(self, x0, y0, width, height, mutation_size)
#    2317             x0, y0 = x0 - pad, y0 - pad
#    2318             x1, y1 = x0 + width, y0 + height
# -> 2319             return Path._create_closed(
#    2320                 [(x0, y0), (x1, y0), (x1, y1), (x0, y1)])
#    2321
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/path.py in _create_closed(cls, vertices)
#     198         """
#     199         v = _to_unmasked_float_array(vertices)
# --> 200         return cls(np.concatenate([v, v[:1]]), closed=True)
#     201
#     202     def _update_values(self):
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# # Example of underfitting (High Bias) in KNN classification

# %%
# evaluate knn performance on train and test sets with different numbers of neighbors
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from matplotlib import pyplot
# create dataset
X, y = make_classification(n_samples=10000, n_features=100, n_classes=3, n_informative=25, n_redundant=5, random_state=13)
# split into train test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
# define lists to collect scores
train_scores, test_scores = list(), list()
# define the tree depths to evaluate
k_values = [i for i in range(1, 30)]
# evaluate a decision tree for each depth
for i in k_values:
	# configure the model
	model = KNeighborsClassifier(n_neighbors=i)
	# fit model on the training dataset
	model.fit(X_train, y_train)
	# evaluate on the train dataset
	train_yhat = model.predict(X_train)
	train_acc = accuracy_score(y_train, train_yhat)
	train_scores.append(train_acc)
	# evaluate on the test dataset
	test_yhat = model.predict(X_test)
	test_acc = accuracy_score(y_test, test_yhat)
	test_scores.append(test_acc)
	# summarize progress
	print('>%d, train: %.3f, test: %.3f' % (i, train_acc, test_acc))
# plot of train and test scores vs number of neighbors
pyplot.plot(k_values, train_scores, '-o', label='Train')
pyplot.plot(k_values, test_scores, '-o', label='Test')
pyplot.legend()
pyplot.show()
# Out:
# >1, train: 1.000, test: 0.822
# >2, train: 0.908, test: 0.783
# >3, train: 0.935, test: 0.850
# >4, train: 0.921, test: 0.841
# >5, train: 0.926, test: 0.864
# >6, train: 0.918, test: 0.857
# >7, train: 0.923, test: 0.871
# >8, train: 0.914, test: 0.863
# >9, train: 0.917, test: 0.868
# >10, train: 0.913, test: 0.866
# >11, train: 0.915, test: 0.870
# >12, train: 0.910, test: 0.869
# >13, train: 0.912, test: 0.871
# >14, train: 0.909, test: 0.868
# >15, train: 0.910, test: 0.874
# >16, train: 0.908, test: 0.873
# >17, train: 0.909, test: 0.877
# >18, train: 0.906, test: 0.877
# >19, train: 0.907, test: 0.875
# >20, train: 0.905, test: 0.875
# >21, train: 0.906, test: 0.871
# >22, train: 0.904, test: 0.873
# >23, train: 0.905, test: 0.871
# >24, train: 0.903, test: 0.870
# >25, train: 0.902, test: 0.874
# >26, train: 0.901, test: 0.872
# >27, train: 0.898, test: 0.872
# >28, train: 0.897, test: 0.867
# >29, train: 0.896, test: 0.873

# %%
#make_classification??

# %%
plot_tree(model)
